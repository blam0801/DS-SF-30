# %% [markdown]
# # DS-SF-30 | Assigment 08: Linear Regression, Part 2

# %% [markdown]
# > In this assignment, we will be using the _seaborn_ library for statistical data visualization.  (http://seaborn.pydata.org/)
# >
# > To install _seaborn_:
# > 1. Exit `Jupyter Notebook`
# >
# > 2. Run the following command in your terminal
# > ```
# > conda install seaborn
# > ```
# >
# > 3. Restart `Jupyter Notebook`

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import seaborn as sns

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-08-advertising.csv'))

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 193   38.2    3.7       13.8    7.6
# 194   94.2    4.9        8.1    9.7
# 195  177.0    9.3        6.4   12.8
# 196  283.6   42.0       66.2   25.5
# 197  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %% [markdown]
# We have 198 observations in this outlier-free dataset.  Each observation records the budget used to run ads on TV, on radio, and in the newspapers (in thousands of dollars) as well as the sale figures (also in thousands of dollars).

# %% [markdown]
# Today, we are going to study if we can predict sales based on the amount of advertising.

# %% [markdown]
# > ## Question 1.  How are the different variables correlated?

# %%
df[['TV', 'Radio', 'Newspaper','Sales']].corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.051978   0.049771  0.779121
# Radio      0.051978  1.000000   0.346364  0.576748
# Newspaper  0.049771  0.346364   1.000000  0.219555
# Sales      0.779121  0.576748   0.219555  1.000000

# %% [markdown]
# Answer: Sales are most correlated to the spend in TV then Radio then Newspaper

# %% [markdown]
# > ## Question 2.  Draw a scatter plot between `TV` (horizontal axis) and `Sales` (vertical axis).

# %%
x = df.TV
y = df.Sales

plt.scatter(x,y)

plt.scatter.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f618b933b4b1> in <module>()
#       4 plt.scatter(x,y)
#       5
# ----> 6 plt.scatter.show()
#
# AttributeError: 'function' object has no attribute 'show'

# %%
df.plot(kind = 'scatter', x = 'TV', y = 'Sales')

# %% [markdown]
# > ## Question 3.  Using _seaborn_, draw the same scatter plot along with a fitted line between `TV` and `Sales`.

# %% [markdown]
# - (http://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %%
x = df.TV
y = df.Sales

sns.lmplot(x, y,'df')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d2f96e6d2773> in <module>()
#       2 y = df.Sales
#       3
# ----> 4 sns.lmplot(x, y,'df')
#
# C:\Users\brandon.lam\AppData\Local\Continuum\Anaconda2\lib\site-packages\seaborn\linearmodels.pyc in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     539     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     540     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 541     data = data[cols]
#     542
#     543     # Initialize the grid
#
# TypeError: string indices must be integers, not list

# %%
sns.lmplot (x='TV', y = 'Sales', data = df)

# %% [markdown]
# > ## Question 4.  Estimate a simple linear regression between `TV` (explanatory variable) and `Sales` (response variable).

# %%
model = smf.ols(formula = 'Sales ~ TV', data =df).fit()

# Response variable comes before the Explanatory Variable 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     302.8
# Date:                Thu, 12 Jan 2017   Prob (F-statistic):           1.29e-41
# Time:                        13:23:00   Log-Likelihood:                -514.27
# No. Observations:                 198   AIC:                             1033.
# Df Residuals:                     196   BIC:                             1039.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      7.0306      0.462     15.219      0.000         6.120     7.942
# ...

# %% [markdown]
# > ## Question 5.  Interpret the coefficients.  Are they significant?  What equation did you derive?

# %% [markdown]
# Answer: Sales is significant beacuse tvalues are greater than zero, the p value is less than 5% and the confidence intervals don't include 0.
#
# Sales = 7.03 +0.0474(TV)
# For the data we have one hand and with evrything else fixed, for every 1000 spent in TV ads, sales increased by 47.

# %% [markdown]
# > ## Question 6.  How are the residual distributed?  Do they follow the linear modeling assumptions?

# %%
# TODO
#60% of the redicual have the found. They have been distributed well and do follow the linear modeling assumptions

# %%
model.resid.mean()
# Out:
# -5.562329497111896e-16

# %%
sm.qqplot(model.resid, line = 's')

# %% [markdown]
# Answer:The residuals follow a normal distribution

# %% [markdown]
# > ## Question 7.  Estimate two new simple linear regression models: (1) `Sales` against `Radio` and (2) `Sales` against `Newspaper`.

# %%
model1 = smf.ols(formula = 'Sales ~ Radio', data =df).fit()

model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     97.69
# Date:                Thu, 12 Jan 2017   Prob (F-statistic):           5.99e-19
# Time:                        13:46:20   Log-Likelihood:                -566.70
# No. Observations:                 198   AIC:                             1137.
# Df Residuals:                     196   BIC:                             1144.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      9.3166      0.560     16.622      0.000         8.211    10.422
# ...

# %%
model2 = smf.ols(formula = 'Sales ~ Newspaper', data =df).fit()

model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     9.927
# Date:                Thu, 12 Jan 2017   Prob (F-statistic):            0.00188
# Time:                        13:46:31   Log-Likelihood:                -601.84
# No. Observations:                 198   AIC:                             1208.
# Df Residuals:                     196   BIC:                             1214.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     12.3193      0.639     19.274      0.000        11.059    13.580
# ...

# %% [markdown]
# > ## Question 8.  What can you conclude of these two new models against the first one?

# %% [markdown]
# Answer: The R2 values are much lower while the coffeeicients appear to be significant
#
# There is also relative high values of f values but are still lower than the one for TV

# %% [markdown]
# > ## Question 9.  Run a multiple linear regression using `TV`, `Radio`, and `Newspaper` as explanatory variables.

# %%
smf.ols(formula = 'Sales ~ TV + Radio + Newspaper', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     553.5
# Date:                Thu, 12 Jan 2017   Prob (F-statistic):           8.35e-95
# Time:                        13:53:57   Log-Likelihood:                -383.24
# No. Observations:                 198   AIC:                             774.5
# Df Residuals:                     194   BIC:                             787.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.9523      0.318      9.280      0.000         2.325     3.580
# ...

# %% [markdown]
# > ## Question 10.  What are your findings?

# %% [markdown]
# Answer: Newspapers was no longer significant after loooking at the three response variables together and should be removed from the model
#
# Adding Radio improves the R2 number significantly
